# %% [markdown]
# # Sequential Agent
#
# If you have a flow you need built. Railtracks can do it very simply

# %% [markdown]
# The magic of railtracks is everything can be done in code, there is no API you need to learn, its pure python logic

# %%
import railtracks as rt
from dotenv import load_dotenv
from tavily import TavilyClient
import os

_ = load_dotenv()

tav_client = TavilyClient(os.environ["TAVILY_SEARCH_API_KEY"])

# %% [markdown]
# ## Lead Pipeline
#
# Image to come.

# %%
from collections import defaultdict

def format_result(title: str, content: str, url: str) -> str:
    return f"Title: {title}\nContent: {content}\nURL: {url}\n"

@rt.function_node
def query_internet(query: str) -> str:
    results = tav_client.search(query, num_results=5)


    formatted_results = "\n".join([format_result(res.get('title', 'Title Unavailable'), res.get('content', 'Content Unavailable'), res.get('url', "Unknown")) for res in results["results"]])
    return f"Top search results for '{query}':\n\n{formatted_results}"



def format_thoughts(thoughts: dict[str, str | None]):
    strings = []
    for thought, resolved in thoughts.items():
        strings.append(f"- {thought}: {resolved if resolved is not None else 'Unresolved'}")
    return "\n".join(strings)


@rt.function_node
def add_thought(thought: str) -> str:
    current_phase = rt.context.get("current_phase")

    thought_store = rt.context.get("thought_store")

    thought_store[current_phase][thought] = None

    task_list_str = format_thoughts(thought_store[current_phase])

    return f"Added thought {thought}.\n\nThe current thought list contains\n{task_list_str}\n"

@rt.function_node
def review_thoughts():
    current_phase = rt.context.get("current_phase")

    thought_store = rt.context.get("thought_store")

    return format_thoughts(thought_store[current_phase])

@rt.function_node
def resolve_thoughts(thought: str, resolved: str):
    """Resolves a given thought with the text provided
    """

    thought_store = rt.context.get("thought_store")
    current_phase = rt.context.get("current_phase")
    if thought not in thought_store[current_phase]:
        raise KeyError(f"Thought '{thought}' does not exist.")
    
    thought_store[current_phase][thought] = resolved

    return f"Resolved {thought} with {resolved}"


thought_manager = [resolve_thoughts, review_thoughts, add_thought]

# %%
# Out:
# Top search results for 'Tell me about google':
#
# Title: 12-35 Tell me about Google Technology - Google 101 Facts
# Content: Google received high marks for its accurate and relevant search results, as well as its user-friendly interface and wide range of features. However, each search
# URL: https://www.steegle.com/about/google-101-facts/12-35-google-technology
#
# Title: What is Google? - Tech Monitor
# Content: # What is Google? The company has operated since the late 1990s and is one of the most fundamental forces in the development of the internet as we know it – to the point where the phrase ‘googling’ is synonymous with using a search engine. While the search engine is the company’s flagship product, Google operates in numerous areas including hardware, cloud computing, advertising, software and AI. Google is now under the umbrella of Alphabet Inc., a publicly traded company with multiple classes of shareholders. Like many of the major public-facing tech companies, advertising is at the heart of Google’s business model. The company uses its AdSense and DoubleClick platforms to perform targeted advertising both on the search engine and on third-party websites via Google Ads. Google, including its full suite of products and services, is just one subsidiary of Alphabet. In 2014, Google purchased British artificial intelligence company DeepMind before it came under the banner of Alphabet during the company restructuring in 2015.
# URL: https://www.techmonitor.ai/what-is/what-is-google/
#
# Title: Google - Wikipedia
# Content: [Jump to content](https://en.wikipedia.org/wiki/Google#bodyContent) *   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [x]") *   [(Top)](https://en.wikipedia.org/wiki/Google#) *   [1 History](https://en.wikipedia.org/wiki/Google#History)Toggle History subsection *   [1.1 Early years](https://en.wikipedia.org/wiki/Google#Early_years) *   [1.2 Growth](https://en.wikipedia.org/wiki/Google#Growth) *   [1.4 2012 onwards](https://en.wikipedia.org/wiki/Google#2012_onwards) *   [2.1 Search engine](https://en.wikipedia.org/wiki/Google#Search_engine) *   [2.2 Advertising](https://en.wikipedia.org/wiki/Google#Advertising) *   [2.4 Consumer services](https://en.wikipedia.org/wiki/Google#Consumer_services) *   [2.4.2 Software](https://en.wikipedia.org/wiki/Google#Software) *   [2.4.3 Hardware](https://en.wikipedia.org/wiki/Google#Hardware) *   [2.5 Enterprise services](https://en.wikipedia.org/wiki/Google#Enterprise_services) *   [2.6 Internet services](https://en.wikipedia.org/wiki/Google#Internet_services) *   [2.7 Financial services](https://en.wikipedia.org/wiki/Google#Financial_services) *   [3.1 Business trends](https://en.wikipedia.org/wiki/Google#Business_trends) *   [3.3 Corporate identity](https://en.wikipedia.org/wiki/Google#Corporate_identity) *   [3.5 Office locations](https://en.wikipedia.org/wiki/Google#Office_locations) *   [3.5.1 North America](https://en.wikipedia.org/wiki/Google#North_America) *   [3.5.2 Latin America](https://en.wikipedia.org/wiki/Google#Latin_America) *   [3.5.3 Europe](https://en.wikipedia.org/wiki/Google#Europe) *   [3.5.4 Asia–Pacific](https://en.wikipedia.org/wiki/Google#Asia%E2%80%93Pacific) *   [3.6 Infrastructure](https://en.wikipedia.org/wiki/Google#Infrastructure) *   [3.7 Environment](https://en.wikipedia.org/wiki/Google#Environment) *   [3.8 Philanthropy](https://en.wikipedia.org/wiki/Google#Philanthropy) *   [4.1 Political controversies](https://en.wikipedia.org/wiki/Google#Political_controversies) *   [4.1.1 United States](https://en.wikipedia.org/wiki/Google#United_States) *   [4.1.2 Brazil](https://en.wikipedia.org/wiki/Google#Brazil) *   [4.1.4 Russia](https://en.wikipedia.org/wiki/Google#Russia) *   [4.2 Antitrust](https://en.wikipedia.org/wiki/Google#Antitrust) *   [4.2.1 European Union](https://en.wikipedia.org/wiki/Google#European_Union) *   [4.2.2 United States](https://en.wikipedia.org/wiki/Google#United_States_2) *   [4.4 Censorship](https://en.wikipedia.org/wiki/Google#Censorship) *   [4.5 Data loss](https://en.wikipedia.org/wiki/Google#Data_loss) *   [4.6 Data privacy](https://en.wikipedia.org/wiki/Google#Data_privacy) *   [4.6.1 Geolocation](https://en.wikipedia.org/wiki/Google#Geolocation) *   [4.6.2 Copyright infringement](https://en.wikipedia.org/wiki/Google#Copyright_infringement) *   [5 See also](https://en.wikipedia.org/wiki/Google#See_also) *   [6 Notes](https://en.wikipedia.org/wiki/Google#Notes) *   [7 References](https://en.wikipedia.org/wiki/Google#References) *   [8 Further reading](https://en.wikipedia.org/wiki/Google#Further_reading) *   [9 External links](https://en.wikipedia.org/wiki/Google#External_links) *   [Google](https://en.wikipedia.org/wiki/Category:Google "Category:Google") 182 languages[Add topic](https://en.wikipedia.org/wiki/Google#)
# URL: https://en.wikipedia.org/wiki/Google
#
# Title: Google | History & Facts; Products & Services | Britannica Money
# Content: * Strategic acquisitions and monetizing Google’s search engine. # Google. * Strategic acquisitions and monetizing Google’s search engine. Google is an American search engine company, founded in 1998 by Sergey Brin and Larry Page. Since 2015, Google has been a subsidiary of the holding company Alphabet, Inc. More than 70% of worldwide online search requests are handled by Google, placing it at the heart of most Internet users’ experience. Google began as an online search firm, but it now offers more than 50 Internet services and products, from e-mail and online document creation to software for mobile phones and tablet computers. In 2023, Alphabet took in $175 billion in revenue (57% of all Google revenue) from advertising based on users’ search requests. That growth only continued; by the end of 2011, Google was handling some three billion searches per day. To *google* became a common expression for searching the Internet. ## Strategic acquisitions and monetizing Google’s search engine.
# URL: https://www.britannica.com/money/Google-Inc
#
# Title: How we started and where we are today - About Google
# Content: [Jump to Content](https://about.google/company-info/our-story/#page-content). [![Image 1: Google logo](https://www.gstatic.com/marketing-cms/assets/images/f5/d3/a7f9db7045429cb6dc6be56bdcbe/google-logo-about.svg)](https://about.google/ "Google"). *   [Products](https://about.google/products/). *   [Company Info](https://about.google/company-info/). *   [News](https://blog.google/?utm_source=about.google&utm_medium=referral&utm_campaign=navigation). (The tradition of keeping things[colorful](https://www.google.com/search?q=google+office+locations&espv=2&biw=2560&bih=1253&site=webhp&source=lnms&tbm=isch&sa=X&ved=0CAYQ_AUoAWoVChMIv-ih3J7exwIVx0qICh3-DQ-Q)continues to this day.). Even in the beginning, things were unconventional: from Google’s initial server (made of Lego) to the [first “Doodle”](https://www.google.com/doodles/burning-man-festival)in 1998: a stick figure in the logo announcing to site visitors that the entire staff was playing hooky at the Burning Man Festival. *   [Blog](https://www.blog.google/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Brand Resource Center](https://about.google/brand-resource-center/). *   [Careers](https://careers.google.com/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Contact us](https://about.google/company-info/contact-google/). *   [Help Center](https://support.google.com/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Investor Relations](https://abc.xyz/investor/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Locations](https://about.google/company-info/locations/). *   [Press resources](https://www.blog.google/press/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Accessibility](https://google.com/accessibility?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Crisis Response](https://crisisresponse.google/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Google.org](https://www.google.org/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Google for Health](https://health.google/?utm_source=about_google&utm_medium=web&utm_content=footer). *   [Grow with Google](https://grow.google/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Learning](https://learning.google/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Public Policy](https://publicpolicy.google/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Sustainability](https://sustainability.google/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Google AI](https://ai.google/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Google Cloud](https://cloud.google.com/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Google DeepMind](https://deepmind.google/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Google for Developers](https://developers.google.com/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Google Labs](https://labs.google/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Google Research](https://research.google/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Around the globe](https://about.google/around-the-globe/). *   [Human rights](https://about.google/company-info/human-rights/). *   [Safety Center](https://safety.google/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). *   [Supplier responsibility](https://sustainability.google/progress/supplier-responsibility/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Transparency Center](https://transparency.google/?utm_source=about.google&utm_medium=referral&utm_campaign=footer). *   [Transparency Report](https://transparencyreport.google.com/?utm_source=about&utm_medium=referral&utm_campaign=footer-link). [![Image 3: Google logo in dark gray](h ...
# URL: https://about.google/company-info/our-story/

# %%
from typing import Optional, List
from pydantic import BaseModel, Field

class Companies(BaseModel):
   companies: List["Company"] = Field(description="List of qualified companies")
class Company(BaseModel):
    name: str = Field(description="Official company name")
    employee_count: Optional[int] = Field(description="Number of employees")
    estimated_revenue: Optional[str] = Field(description="Estimated annual revenue")
    area_of_expertise: str = Field(description="Primary business focus or industry vertical")
    tech_stack: List[str] = Field(default_factory=list, description="Known technologies and tools in use")
    url: str = Field(description="Company website URL")
    linkedin: str = Field(description="Company LinkedIn profile URL")
    why_good_fit: str = Field(description="Brief explanation of why this company is a good prospect for the product offering")
    data_sources: List[str] = Field(default_factory=list, description="URLs where information was gathered")


LEAD_FINDER_SYSTEM = """You are an in-depth research agent specialized in identifying and qualifying companies as potential sales prospects.

# YOUR MISSION
You will be provided with a product offering or service to sell. Your job is to find 10-20 companies that would be excellent prospects for this offering. You are the FIRST FILTER in a larger sales process - your goal is to identify and lightly qualify companies, not to do exhaustive research on each one.

# RESEARCH METHODOLOGY

## Phase 1: Strategic Planning (Use Thought Management)
Before searching, you MUST use the thought management tools to plan your approach:
- Use `add_thought` to brainstorm: What industries would need this product? What company characteristics indicate a good fit?
- Document your search strategy: What search queries will you run? What signals will you look for?
- Create a research checklist of information you need to gather for each company

## Phase 2: Broad Discovery
- Execute broad searches to identify potential companies in relevant industries
- Cast a wide net - look for companies that MIGHT fit based on industry, size, or business model
- Use `add_thought` to track promising leads and patterns you notice
- Use `resolve_thoughts` to mark completed searches and document findings

## Phase 3: Company Qualification (Multi-Pass)
For each promising company, conduct a focused investigation:

**First Pass - Basic Fit:**
- Confirm the company is real and active
- Verify industry alignment with the product offering
- Check approximate company size (employees)
- Initial assessment: Does this seem like a prospect worth investigating further?

**Second Pass - Deeper Details:**
- Find specific employee count and revenue estimates
- Identify their current tech stack or tools (look at job postings, tech detection sites, engineering blogs, case studies)
- Find their LinkedIn company page
- Determine WHY they would need your product offering

**Between passes:** Use `review_thoughts` regularly to ensure you're staying on track and haven't missed anything.

## Phase 4: Documentation & Finalization
- Use `resolve_thoughts` to mark each company as fully researched
- Ensure you have 10-20 high-confidence companies
- Double-check that each company has all required fields, especially LinkedIn URLs

# CRITICAL REQUIREMENTS

1. **Always use thought management tools BEFORE conducting research**
   - Never start searching without first planning your approach
   - Regularly check in with your thought list to track progress

2. **Only include HIGH CONFIDENCE companies**
   - You must be confident in the fit between the company and the product
   - If you can't find sufficient information, move on to other prospects

3. **Maximum 20 companies**
   - Focus on quality over quantity
   - Better to have 12 excellent prospects than 20 mediocre ones

4. **LinkedIn is mandatory**
   - Every company MUST have a LinkedIn URL
   - This is critical for downstream processes

5. **Think about the pitch angle**
   - For each company, you should have a clear sense of why they need this product
   - This helps you evaluate fit and will be documented in `why_good_fit`

# SEARCH STRATEGY TIPS

- Use multiple search queries per industry vertical
- Look for recent news, funding announcements, or growth signals
- Check job postings to understand their tech stack and pain points
- Cross-reference multiple sources to verify company information
- If a company seems perfect but you can't verify key details, note this in your thoughts and decide whether to include them

# OUTPUT FORMAT

When you have completed your research, output your findings in the following structured text format for each company:

---COMPANY---
NAME: [Company Name]
EMPLOYEE_COUNT: [Number of employees, or null if unknown]
ESTIMATED_REVENUE: [Revenue estimate like "$10M-$50M ARR", or null if unknown]
AREA_OF_EXPERTISE: [Primary business focus]
TECH_STACK: [Comma-separated list of technologies]
URL: [Company website]
LINKEDIN: [LinkedIn company page URL]
WHY_GOOD_FIT: [2-3 sentence explanation of why they're a good prospect]
DATA_SOURCES: [Comma-separated list of URLs where you found this information]
---END---

Example:
---COMPANY---
NAME: Acme Analytics
EMPLOYEE_COUNT: 150
ESTIMATED_REVENUE: $20M-$30M ARR
AREA_OF_EXPERTISE: B2B SaaS analytics platform for e-commerce
TECH_STACK: Python, React, PostgreSQL, AWS, Segment
URL: https://acmeanalytics.com
LINKEDIN: https://linkedin.com/company/acme-analytics
WHY_GOOD_FIT: Mid-size analytics company likely dealing with data pipeline challenges. Their job postings mention scaling issues with data infrastructure, which directly aligns with our data orchestration product.
DATA_SOURCES: https://acmeanalytics.com/careers, https://linkedin.com/company/acme-analytics, https://builtwith.com/acmeanalytics.com
---END---

Remember: You are the gatekeeper. Only companies that genuinely fit the offering should make it through your filter."""

# %%
# ============================================================================
# CONTACT BASE MODEL
# ============================================================================
class Contacts(BaseModel):
   contacts: List["Contact"] = Field(description="List of qualified contacts")
   
class Contact(BaseModel):
    full_name: str = Field(description="Contact's full name")
    title: str = Field(description="Job title/role")
    department: Optional[str] = Field(description="Department (Sales, Engineering, etc.)")
    linkedin_url: str = Field(description="LinkedIn profile URL")
    email: Optional[str] = Field(description="Email address if found")
    phone: Optional[str] = Field(description="Phone number if found")
    why_relevant: str = Field(description="Why this person is a relevant contact for the product offering")
    company_name: str = Field(description="Company this contact works for")
    data_sources: List[str] = Field(default_factory=list, description="URLs where information was found")


# ============================================================================
# COMPANY TO STRING CONVERTER
# ============================================================================

def company_to_llm_string(company: Company) -> str:
    """Converts a Company object into a readable string representation for LLM processing."""
    
    tech_stack_str = ", ".join(company.tech_stack) if company.tech_stack else "Unknown"
    data_sources_str = "\n  - ".join(company.data_sources) if company.data_sources else "None provided"
    
    return f"""
COMPANY PROFILE
===============

Company Name: {company.name}
Website: {company.url}
LinkedIn: {company.linkedin}

SIZE & SCOPE
------------
Employees: {company.employee_count if company.employee_count else "Unknown"}
Estimated Revenue: {company.estimated_revenue if company.estimated_revenue else "Unknown"}
Area of Expertise: {company.area_of_expertise}

TECHNOLOGY
----------
Current Tech Stack: {tech_stack_str}

SALES CONTEXT
-------------
Why Good Fit: {company.why_good_fit}

RESEARCH SOURCES
----------------
  - {data_sources_str}
""".strip()


# ============================================================================
# CONTACT FINDER SYSTEM PROMPT
# ============================================================================

CONTACT_FINDER_SYSTEM = """You are a specialized research agent focused on identifying key decision-makers and relevant contacts at a specific company.

# YOUR MISSION
You will be provided with:
1. A company profile (name, size, industry, tech stack)
2. A product offering we want to sell to this company

Your job is to find 5-10 relevant contacts at this company who would be involved in evaluating, purchasing, or implementing this type of product.

# WHO TO FIND

Focus on decision-makers and influencers who would be involved in the buying process:

**Primary Targets (High Priority):**
- C-Suite executives (CEO, CTO, CIO, CDO, etc.) at smaller companies (<200 employees)
- VPs and Directors (Engineering, Product, Operations, IT, Data, etc.)
- Heads of relevant departments

**Secondary Targets (Medium Priority):**
- Senior managers in relevant teams
- Technical leads or architects who influence tool selection
- Product managers overseeing relevant areas

**Avoid:**
- Junior individual contributors (unless at very small companies)
- Recruiters or HR (unless selling HR product)
- Interns or entry-level roles

# RESEARCH METHODOLOGY

## Phase 1: Strategic Planning (Use Thought Management)
Before searching, use thought management tools to plan:
- Use `add_thought` to identify: What roles/titles would be involved in buying this product?
- Document your search strategy: Where will you look? What keywords will you use?
- Create a checklist of information to gather for each contact

## Phase 2: Broad Contact Discovery
Execute searches to find potential contacts:
- Search LinkedIn for employees with relevant titles
- Look at the company's "About" or "Team" pages
- Check recent press releases or news for quoted executives
- Review conference speaker lists, podcast appearances, webinars
- Look at GitHub contributors (for technical products)
- Use `add_thought` to track promising contacts and patterns

## Phase 3: Contact Qualification (Multi-Pass)

**First Pass - Identify Candidates:**
- Compile a list of 15-20 potential contacts with relevant titles
- Verify they currently work at the company (check for recent activity)
- Assess their likely influence in the buying decision

**Second Pass - Gather Details:**
- Find their LinkedIn profile URL (MANDATORY)
- Determine their exact title and department
- Look for email addresses (company website, GitHub, social profiles, conference materials)
- Look for phone numbers if publicly available
- Understand their role and why they're relevant to the product

**Third Pass - Prioritization:**
- Select the 5-10 BEST contacts (quality over quantity)
- Ensure diversity of roles (don't just find 10 engineers)
- Use `review_thoughts` to confirm you have the right mix

## Phase 4: Documentation & Finalization
- Use `resolve_thoughts` to mark each contact as fully researched
- Ensure you have 5-10 high-quality contacts
- Double-check that each contact has a LinkedIn URL (MANDATORY)

# CRITICAL REQUIREMENTS

1. **Always use thought management tools BEFORE searching**
   - Plan your approach before executing searches
   - Regularly check in with your thought list to track progress

2. **LinkedIn URLs are MANDATORY**
   - Every contact MUST have a LinkedIn profile URL
   - This is the most critical piece of information

3. **Focus on decision-makers**
   - Prioritize people who can actually say "yes" to a purchase
   - Consider the company size when determining seniority level

4. **5-10 contacts per company**
   - Better to have 6 excellent contacts than 10 mediocre ones
   - Aim for a mix of roles and seniority levels

5. **Explain relevance**
   - For each contact, clearly articulate why they're relevant
   - Connect their role to the product offering

# SEARCH STRATEGY TIPS

- Start with LinkedIn: "site:linkedin.com/in [Company Name] [Title]"
- Check company website team/about pages
- Look for recent company news mentioning specific people
- Search for the company name + role on Google
- Check if the company has an engineering blog with author bios
- Look at recent job postings - hiring managers are often listed
- For technical products, check GitHub for company organization members

# OUTPUT FORMAT

When you have completed your research, output your findings in the following structured text format for each contact:

---CONTACT---
FULL_NAME: [First Last]
TITLE: [Job Title]
DEPARTMENT: [Department name, or null if unknown]
LINKEDIN_URL: [LinkedIn profile URL]
EMAIL: [Email address, or null if not found]
PHONE: [Phone number, or null if not found]
WHY_RELEVANT: [2-3 sentence explanation of why this person is a relevant contact]
COMPANY_NAME: [Company name they work for]
DATA_SOURCES: [Comma-separated list of URLs where you found this information]
---END---

Example:
---CONTACT---
FULL_NAME: Sarah Johnson
TITLE: VP of Engineering
DEPARTMENT: Engineering
LINKEDIN_URL: https://linkedin.com/in/sarah-johnson-tech
EMAIL: sarah.johnson@acmeanalytics.com
PHONE: null
WHY_RELEVANT: As VP of Engineering at a mid-size analytics company, Sarah would be the primary decision-maker for data infrastructure tools. Her team is scaling and likely experiencing the exact pain points our product solves.
COMPANY_NAME: Acme Analytics
DATA_SOURCES: https://linkedin.com/in/sarah-johnson-tech, https://acmeanalytics.com/team
---END---

Remember: These contacts will be used for outreach. Only include people who are genuinely relevant and whose information you are confident about."""


# ============================================================================
# CONTACT PARSER SYSTEM PROMPT
# ============================================================================

CONTACT_PARSER_SYSTEM = """You are a specialized parsing agent that consolidates contact research into structured data.

# YOUR MISSION
You will receive raw text output from multiple contact research agents, each containing information about contacts found at different companies. Your job is to:

1. Parse all the contact information from the raw text
2. Validate that each contact has the required fields (especially LinkedIn URL)
3. Remove any duplicates
4. Output the final consolidated list in the proper structured format

# PARSING INSTRUCTIONS

Each contact in the input will be formatted as:
---CONTACT---
FULL_NAME: [name]
TITLE: [title]
DEPARTMENT: [dept or null]
LINKEDIN_URL: [url]
EMAIL: [email or null]
PHONE: [phone or null]
WHY_RELEVANT: [explanation]
COMPANY_NAME: [company]
DATA_SOURCES: [urls]
---END---

# VALIDATION RULES

For each contact, ensure:
1. **FULL_NAME is present and valid** - Must have at least first and last name
2. **TITLE is present** - Cannot be null or empty
3. **LINKEDIN_URL is present and valid** - This is MANDATORY, must be a real LinkedIn URL
4. **COMPANY_NAME is present** - Must match one of the companies being researched
5. **WHY_RELEVANT is present** - Must have explanation

If a contact is missing any of these critical fields, EXCLUDE it from the final output.

# DEDUPLICATION

If you find the same person listed multiple times (same name + company):
- Keep the entry with the most complete information
- Merge data_sources from both entries
- Use the most detailed WHY_RELEVANT explanation


YOU MUST complete all phases before returning the final output. It should contain the format specified above with little extra text.
"""

# %%
LeadFinder = rt.agent_node(
   name="Lead Finder",
    system_message=LEAD_FINDER_SYSTEM,
    tool_nodes=[query_internet, *thought_manager],
    llm=rt.llm.OpenAILLM("gpt-4.1"),
)

LeadFinderParser = rt.agent_node(
    name="Lead Finder Parser",
    system_message="You are a meticulous data parser. Your job is to extract structured company information from an input and put it into a structured form.",
    output_schema=Companies,
    llm=rt.llm.OpenAILLM("gpt-4.1"),
)

ContactFinder = rt.agent_node(
    name="Contact Finder",
    system_message=CONTACT_FINDER_SYSTEM,
    tool_nodes=[query_internet, *thought_manager],
    llm=rt.llm.OpenAILLM("gpt-4.1"),
)

ContactFinderParser = rt.agent_node(
    name="Contact Finder Parser",
    system_message=CONTACT_PARSER_SYSTEM,
    output_schema=Contacts,
    llm=rt.llm.OpenAILLM("gpt-4.1"),
)

# %%
import asyncio


thought_store: dict[str, dict[str, str | None]] = defaultdict(dict)

@rt.session(context={"current_phase": "Lead Finding", "thought_store": thought_store})
async def flow():
    result = await rt.call(LeadFinder, "An tool that allows canadian companies to sred their work with ease. it is designed for mid level companies who do not have to pay a consulting firm and would prefer to use some sort of saas platform instead.")

    compainies = await rt.call(LeadFinderParser, result.text)

    rt.context.put("current_phase", "Contact Searching")
    contacts: dict[str, list[Contact]] = {}
    for company in compainies.structured.companies:
        company_str = company_to_llm_string(company)
        contact_results = await rt.call(ContactFinder, f"Find relevant contacts at the following company for selling our product:\n\n{company_str}\n\nProduct Offering: An agentic framework aimed at devs to help them build agents with ease. It offers a fully customizable python API. Paying products include a vizualization and sharing tooling for to view your runs through history.")
        contacts_list = await rt.call(ContactFinderParser, contact_results.text)

        contacts[company.name] = contacts_list.structured.contacts

    return contacts

# %%
companies, _ = await flow()
# Out:
# [+6066.012s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6066.014s] RT          : INFO     - START CREATED Lead Finder
# [+6068.285s] RT          : INFO     - Lead Finder CREATED add_thought
# [+6068.285s] RT          : INFO     - add_thought DONE
# [+6070.868s] RT          : INFO     - Lead Finder CREATED add_thought
# [+6070.878s] RT          : INFO     - add_thought DONE
# [+6076.306s] RT          : INFO     - Lead Finder CREATED add_thought
# [+6076.309s] RT          : INFO     - add_thought DONE
# [+6080.012s] RT          : INFO     - Lead Finder CREATED add_thought
# [+6080.015s] RT          : INFO     - add_thought DONE
# [+6083.276s] RT          : INFO     - Lead Finder CREATED resolve_thoughts
# [+6083.276s] RT          : INFO     - resolve_thoughts DONE
# [+6087.291s] RT          : INFO     - Lead Finder CREATED resolve_thoughts
# [+6087.302s] RT          : INFO     - resolve_thoughts DONE
# [+6089.888s] RT          : INFO     - Lead Finder CREATED resolve_thoughts
# [+6089.888s] RT          : INFO     - resolve_thoughts DONE
# [+6095.347s] RT          : INFO     - Lead Finder CREATED resolve_thoughts
# [+6095.351s] RT          : INFO     - resolve_thoughts DONE
# [+6097.614s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6097.620s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6097.624s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6097.628s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6097.632s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6098.696s] RT          : INFO     - query_internet DONE
# [+6098.711s] RT          : INFO     - query_internet DONE
# [+6098.719s] RT          : INFO     - query_internet DONE
# [+6098.803s] RT          : INFO     - query_internet DONE
# [+6099.681s] RT          : INFO     - query_internet DONE
# [+6103.628s] RT          : INFO     - Lead Finder CREATED add_thought
# [+6103.628s] RT          : INFO     - add_thought DONE
# [+6107.723s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.726s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.729s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.729s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.740s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.743s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.748s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.752s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.754s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6107.761s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6108.779s] RT          : INFO     - query_internet DONE
# [+6108.829s] RT          : INFO     - query_internet DONE
# [+6108.859s] RT          : INFO     - query_internet DONE
# [+6108.882s] RT          : INFO     - query_internet DONE
# [+6108.898s] RT          : INFO     - query_internet DONE
# [+6108.945s] RT          : INFO     - query_internet DONE
# [+6109.112s] RT          : INFO     - query_internet DONE
# [+6109.246s] RT          : INFO     - query_internet DONE
# [+6109.345s] RT          : INFO     - query_internet DONE
# [+6109.495s] RT          : INFO     - query_internet DONE
# [+6111.563s] RT          : INFO     - Lead Finder CREATED review_thoughts
# [+6111.567s] RT          : INFO     - review_thoughts DONE
# [+6116.296s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.304s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.310s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.312s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.318s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.324s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.328s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.330s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.337s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6116.341s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6117.323s] RT          : INFO     - query_internet DONE
# [+6117.380s] RT          : INFO     - query_internet DONE
# [+6117.451s] RT          : INFO     - query_internet DONE
# [+6117.470s] RT          : INFO     - query_internet DONE
# [+6117.477s] RT          : INFO     - query_internet DONE
# [+6117.510s] RT          : INFO     - query_internet DONE
# [+6117.513s] RT          : INFO     - query_internet DONE
# [+6117.670s] RT          : INFO     - query_internet DONE
# [+6117.729s] RT          : INFO     - query_internet DONE
# [+6117.904s] RT          : INFO     - query_internet DONE
# [+6121.429s] RT          : INFO     - Lead Finder CREATED add_thought
# [+6121.429s] RT          : INFO     - add_thought DONE
# [+6124.913s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.913s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.922s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.925s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.930s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.931s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.939s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.943s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.948s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6124.952s] RT          : INFO     - Lead Finder CREATED query_internet
# [+6125.927s] RT          : INFO     - query_internet DONE
# [+6125.930s] RT          : INFO     - query_internet DONE
# [+6125.933s] RT          : INFO     - query_internet DONE
# [+6125.954s] RT          : INFO     - query_internet DONE
# [+6126.039s] RT          : INFO     - query_internet DONE
# [+6126.113s] RT          : INFO     - query_internet DONE
# [+6126.121s] RT          : INFO     - query_internet DONE
# [+6126.234s] RT          : INFO     - query_internet DONE
# [+6126.347s] RT          : INFO     - query_internet DONE
# [+6126.744s] RT          : INFO     - query_internet DONE
# [+6135.004s] RT          : INFO     - Lead Finder CREATED resolve_thoughts
# [+6135.013s] RT          : INFO     - resolve_thoughts DONE
# [+6182.013s] RT          : INFO     - Lead Finder DONE
# [+6182.019s] RT          : INFO     - START CREATED Lead Finder Parser
# [+6193.760s] RT          : INFO     - Lead Finder Parser DONE
# 10
# [+6193.765s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6193.767s] RT          : INFO     - START CREATED Contact Finder
# [+6200.761s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6200.765s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6200.767s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6200.767s] RT          : INFO     - add_thought DONE
# [+6200.775s] RT          : INFO     - add_thought DONE
# [+6200.778s] RT          : INFO     - add_thought DONE
# [+6202.875s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6202.875s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6202.887s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6202.892s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6202.894s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6202.902s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6203.909s] RT          : INFO     - query_internet DONE
# [+6203.939s] RT          : INFO     - query_internet DONE
# [+6203.946s] RT          : INFO     - query_internet DONE
# [+6204.134s] RT          : INFO     - query_internet DONE
# [+6204.189s] RT          : INFO     - query_internet DONE
# [+6205.584s] RT          : INFO     - query_internet DONE
# [+6207.051s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6209.651s] RT          : INFO     - query_internet DONE
# [+6211.118s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6218.818s] RT          : INFO     - query_internet DONE
# [+6220.072s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6220.077s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6221.245s] RT          : INFO     - query_internet DONE
# [+6228.945s] RT          : INFO     - query_internet DONE
# [+6229.707s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6229.711s] RT          : INFO     - review_thoughts DONE
# [+6240.736s] RT          : INFO     - Contact Finder DONE
# [+6240.736s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6250.414s] RT          : INFO     - Contact Finder Parser DONE
# [+6250.422s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6250.423s] RT          : INFO     - START CREATED Contact Finder
# [+6255.228s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6255.228s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6255.237s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6255.237s] RT          : INFO     - add_thought DONE
# [+6255.245s] RT          : INFO     - add_thought DONE
# [+6255.250s] RT          : INFO     - add_thought DONE
# [+6257.728s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6257.728s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6257.744s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6257.752s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6257.756s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6257.765s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6257.997s] RT          : ERROR    - query_internet FAILED
# Traceback (most recent call last):
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\execution_strategy.py", line 52, in execute
#     result = await invoke_func()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\task.py", line 36, in invoke
#     return await self.node.tracked_invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 149, in tracked_invoke
#     raise e
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 147, in tracked_invoke
#     return await self.invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 81, in async_wrapper
#     return await method(self, *args, **kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\concrete\function_base.py", line 91, in invoke
#     result = await asyncio.to_thread(self.func, *self.args, **self.kwargs)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\_node_builder.py", line 393, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Logan\AppData\Local\Temp\ipykernel_32160\3632667513.py", line 8, in query_internet
#     results = tav_client.search(query, num_results=5)
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 139, in search
#     response_dict = self._search(query,
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 109, in _search
#     raise BadRequestError(detail)
# tavily.errors.BadRequestError: Query is too long. Max query length is 400 characters.
# [+6258.872s] RT          : INFO     - query_internet DONE
# [+6258.872s] RT          : INFO     - query_internet DONE
# [+6258.880s] RT          : INFO     - query_internet DONE
# [+6259.019s] RT          : INFO     - query_internet DONE
# [+6259.368s] RT          : INFO     - query_internet DONE
# [+6261.732s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6261.741s] RT          : INFO     - add_thought DONE
# [+6263.781s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6263.785s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6263.790s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6263.795s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6263.799s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6263.807s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6264.956s] RT          : INFO     - query_internet DONE
# [+6265.012s] RT          : INFO     - query_internet DONE
# [+6265.032s] RT          : INFO     - query_internet DONE
# [+6265.073s] RT          : INFO     - query_internet DONE
# [+6265.118s] RT          : INFO     - query_internet DONE
# [+6265.121s] RT          : INFO     - query_internet DONE
# [+6267.446s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6267.450s] RT          : INFO     - add_thought DONE
# [+6269.595s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6269.595s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6269.606s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6269.611s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6269.617s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6269.623s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6270.501s] RT          : INFO     - query_internet DONE
# [+6270.654s] RT          : INFO     - query_internet DONE
# [+6270.659s] RT          : INFO     - query_internet DONE
# [+6270.692s] RT          : INFO     - query_internet DONE
# [+6270.696s] RT          : INFO     - query_internet DONE
# [+6270.848s] RT          : INFO     - query_internet DONE
# [+6273.016s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6273.026s] RT          : INFO     - add_thought DONE
# [+6273.730s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6273.730s] RT          : INFO     - review_thoughts DONE
# [+6290.004s] RT          : INFO     - Contact Finder DONE
# [+6290.005s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6303.090s] RT          : INFO     - Contact Finder Parser DONE
# [+6303.100s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6303.102s] RT          : INFO     - START CREATED Contact Finder
# [+6308.409s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6308.413s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6308.414s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6308.425s] RT          : INFO     - add_thought DONE
# [+6308.427s] RT          : INFO     - add_thought DONE
# [+6308.431s] RT          : INFO     - add_thought DONE
# [+6310.373s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6310.373s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6310.383s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6310.388s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6310.391s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6310.400s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6311.326s] RT          : INFO     - query_internet DONE
# [+6311.399s] RT          : INFO     - query_internet DONE
# [+6311.427s] RT          : INFO     - query_internet DONE
# [+6311.461s] RT          : INFO     - query_internet DONE
# [+6311.482s] RT          : INFO     - query_internet DONE
# [+6311.814s] RT          : INFO     - query_internet DONE
# [+6313.581s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6313.585s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6313.590s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6313.590s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6313.601s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6313.606s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6314.573s] RT          : INFO     - query_internet DONE
# [+6314.608s] RT          : INFO     - query_internet DONE
# [+6314.627s] RT          : INFO     - query_internet DONE
# [+6314.942s] RT          : INFO     - query_internet DONE
# [+6315.023s] RT          : INFO     - query_internet DONE
# [+6315.173s] RT          : INFO     - query_internet DONE
# [+6315.990s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6320.635s] RT          : INFO     - query_internet DONE
# [+6322.390s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6322.391s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6322.400s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6322.405s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6322.410s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6322.416s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6323.335s] RT          : INFO     - query_internet DONE
# [+6323.433s] RT          : INFO     - query_internet DONE
# [+6323.506s] RT          : INFO     - query_internet DONE
# [+6323.599s] RT          : INFO     - query_internet DONE
# [+6323.617s] RT          : INFO     - query_internet DONE
# [+6323.772s] RT          : INFO     - query_internet DONE
# [+6327.389s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6327.391s] RT          : INFO     - review_thoughts DONE
# [+6345.527s] RT          : INFO     - Contact Finder DONE
# [+6345.530s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6361.518s] RT          : INFO     - Contact Finder Parser DONE
# [+6361.527s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6361.529s] RT          : INFO     - START CREATED Contact Finder
# [+6364.146s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6364.150s] RT          : INFO     - add_thought DONE
# [+6366.790s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6366.793s] RT          : INFO     - add_thought DONE
# [+6368.679s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6368.685s] RT          : INFO     - add_thought DONE
# [+6370.288s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6370.288s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6370.288s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6370.303s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6371.393s] RT          : INFO     - query_internet DONE
# [+6371.468s] RT          : INFO     - query_internet DONE
# [+6371.635s] RT          : INFO     - query_internet DONE
# [+6377.384s] RT          : INFO     - query_internet DONE
# [+6380.513s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6380.526s] RT          : INFO     - add_thought DONE
# [+6384.263s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6384.267s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6384.269s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6384.276s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6384.769s] RT          : ERROR    - query_internet FAILED
# Traceback (most recent call last):
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\execution_strategy.py", line 52, in execute
#     result = await invoke_func()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\task.py", line 36, in invoke
#     return await self.node.tracked_invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 149, in tracked_invoke
#     raise e
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 147, in tracked_invoke
#     return await self.invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 81, in async_wrapper
#     return await method(self, *args, **kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\concrete\function_base.py", line 91, in invoke
#     result = await asyncio.to_thread(self.func, *self.args, **self.kwargs)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\_node_builder.py", line 393, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Logan\AppData\Local\Temp\ipykernel_32160\3632667513.py", line 8, in query_internet
#     results = tav_client.search(query, num_results=5)
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 139, in search
#     response_dict = self._search(query,
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 109, in _search
#     raise BadRequestError(detail)
# tavily.errors.BadRequestError: Query cannot consist only of site: operators. Please provide search terms.
# [+6384.778s] RT          : ERROR    - query_internet FAILED
# Traceback (most recent call last):
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\execution_strategy.py", line 52, in execute
#     result = await invoke_func()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\task.py", line 36, in invoke
#     return await self.node.tracked_invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 149, in tracked_invoke
#     raise e
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 147, in tracked_invoke
#     return await self.invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 81, in async_wrapper
#     return await method(self, *args, **kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\concrete\function_base.py", line 91, in invoke
#     result = await asyncio.to_thread(self.func, *self.args, **self.kwargs)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\_node_builder.py", line 393, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Logan\AppData\Local\Temp\ipykernel_32160\3632667513.py", line 8, in query_internet
#     results = tav_client.search(query, num_results=5)
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 139, in search
#     response_dict = self._search(query,
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 109, in _search
#     raise BadRequestError(detail)
# tavily.errors.BadRequestError: Query cannot consist only of site: operators. Please provide search terms.
# [+6385.295s] RT          : INFO     - query_internet DONE
# [+6385.850s] RT          : INFO     - query_internet DONE
# [+6387.439s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6387.442s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6387.447s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6387.452s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6388.450s] RT          : INFO     - query_internet DONE
# [+6388.529s] RT          : INFO     - query_internet DONE
# [+6388.829s] RT          : INFO     - query_internet DONE
# [+6389.157s] RT          : INFO     - query_internet DONE
# [+6392.112s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6392.119s] RT          : INFO     - add_thought DONE
# [+6392.723s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6392.728s] RT          : INFO     - review_thoughts DONE
# [+6396.296s] RT          : INFO     - Contact Finder CREATED resolve_thoughts
# [+6396.303s] RT          : INFO     - resolve_thoughts DONE
# [+6406.813s] RT          : INFO     - Contact Finder DONE
# [+6406.817s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6414.694s] RT          : INFO     - Contact Finder Parser DONE
# [+6414.699s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6414.701s] RT          : INFO     - START CREATED Contact Finder
# [+6420.706s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6420.711s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6420.715s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6420.719s] RT          : INFO     - add_thought DONE
# [+6420.722s] RT          : INFO     - add_thought DONE
# [+6420.726s] RT          : INFO     - add_thought DONE
# [+6422.451s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6422.456s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6422.460s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6422.466s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6422.749s] RT          : ERROR    - query_internet FAILED
# Traceback (most recent call last):
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\execution_strategy.py", line 52, in execute
#     result = await invoke_func()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\task.py", line 36, in invoke
#     return await self.node.tracked_invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 149, in tracked_invoke
#     raise e
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 147, in tracked_invoke
#     return await self.invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 81, in async_wrapper
#     return await method(self, *args, **kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\concrete\function_base.py", line 91, in invoke
#     result = await asyncio.to_thread(self.func, *self.args, **self.kwargs)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\_node_builder.py", line 393, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Logan\AppData\Local\Temp\ipykernel_32160\3632667513.py", line 8, in query_internet
#     results = tav_client.search(query, num_results=5)
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 139, in search
#     response_dict = self._search(query,
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 109, in _search
#     raise BadRequestError(detail)
# tavily.errors.BadRequestError: Query cannot consist only of site: operators. Please provide search terms.
# [+6423.485s] RT          : INFO     - query_internet DONE
# [+6423.679s] RT          : INFO     - query_internet DONE
# [+6424.505s] RT          : INFO     - query_internet DONE
# [+6425.859s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6425.865s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6425.869s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6425.875s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6425.880s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6427.041s] RT          : INFO     - query_internet DONE
# [+6427.046s] RT          : INFO     - query_internet DONE
# [+6427.106s] RT          : INFO     - query_internet DONE
# [+6427.127s] RT          : INFO     - query_internet DONE
# [+6427.161s] RT          : INFO     - query_internet DONE
# [+6428.124s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6428.129s] RT          : INFO     - review_thoughts DONE
# [+6441.516s] RT          : INFO     - Contact Finder DONE
# [+6441.520s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6454.768s] RT          : INFO     - Contact Finder Parser DONE
# [+6454.773s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6454.774s] RT          : INFO     - START CREATED Contact Finder
# [+6457.453s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6457.458s] RT          : INFO     - add_thought DONE
# [+6460.304s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6460.309s] RT          : INFO     - add_thought DONE
# [+6461.958s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6461.961s] RT          : INFO     - add_thought DONE
# [+6463.746s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6463.750s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6463.755s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6463.760s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6463.766s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6464.191s] RT          : ERROR    - query_internet FAILED
# Traceback (most recent call last):
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\execution_strategy.py", line 52, in execute
#     result = await invoke_func()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\execution\task.py", line 36, in invoke
#     return await self.node.tracked_invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 149, in tracked_invoke
#     raise e
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 147, in tracked_invoke
#     return await self.invoke()
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\nodes\nodes.py", line 81, in async_wrapper
#     return await method(self, *args, **kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\concrete\function_base.py", line 91, in invoke
#     result = await asyncio.to_thread(self.func, *self.args, **self.kwargs)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\asyncio\threads.py", line 25, in to_thread
#     return await loop.run_in_executor(None, func_call)
#   File "C:\Users\Logan\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\Logan\Documents\rc\packages\railtracks\src\railtracks\built_nodes\_node_builder.py", line 393, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\Logan\AppData\Local\Temp\ipykernel_32160\3632667513.py", line 8, in query_internet
#     results = tav_client.search(query, num_results=5)
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 139, in search
#     response_dict = self._search(query,
#   File "c:\Users\Logan\Documents\rc\.venv\lib\site-packages\tavily\tavily.py", line 109, in _search
#     raise BadRequestError(detail)
# tavily.errors.BadRequestError: Query cannot consist only of site: operators. Please provide search terms.
# [+6464.897s] RT          : INFO     - query_internet DONE
# [+6464.973s] RT          : INFO     - query_internet DONE
# [+6465.033s] RT          : INFO     - query_internet DONE
# [+6465.091s] RT          : INFO     - query_internet DONE
# [+6466.296s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6466.302s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6466.306s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6466.310s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6466.316s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6467.369s] RT          : INFO     - query_internet DONE
# [+6467.374s] RT          : INFO     - query_internet DONE
# [+6467.429s] RT          : INFO     - query_internet DONE
# [+6467.609s] RT          : INFO     - query_internet DONE
# [+6468.202s] RT          : INFO     - query_internet DONE
# [+6469.091s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6470.458s] RT          : INFO     - query_internet DONE
# [+6471.485s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6471.490s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6471.495s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6472.544s] RT          : INFO     - query_internet DONE
# [+6472.578s] RT          : INFO     - query_internet DONE
# [+6472.884s] RT          : INFO     - query_internet DONE
# [+6473.608s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6474.931s] RT          : INFO     - query_internet DONE
# [+6475.603s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6476.544s] RT          : INFO     - query_internet DONE
# [+6477.504s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6477.509s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6477.513s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6478.610s] RT          : INFO     - query_internet DONE
# [+6478.634s] RT          : INFO     - query_internet DONE
# [+6478.798s] RT          : INFO     - query_internet DONE
# [+6480.462s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6482.450s] RT          : INFO     - query_internet DONE
# [+6483.272s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6484.210s] RT          : INFO     - query_internet DONE
# [+6484.911s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6485.936s] RT          : INFO     - query_internet DONE
# [+6488.869s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6488.875s] RT          : INFO     - add_thought DONE
# [+6492.713s] RT          : INFO     - Contact Finder CREATED resolve_thoughts
# [+6492.718s] RT          : INFO     - resolve_thoughts DONE
# [+6499.222s] RT          : INFO     - Contact Finder DONE
# [+6499.226s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6510.965s] RT          : INFO     - Contact Finder Parser DONE
# [+6510.969s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6510.971s] RT          : INFO     - START CREATED Contact Finder
# [+6515.298s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6515.302s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6515.306s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6515.311s] RT          : INFO     - add_thought DONE
# [+6515.314s] RT          : INFO     - add_thought DONE
# [+6515.318s] RT          : INFO     - add_thought DONE
# [+6518.320s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6518.324s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6518.329s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6518.334s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6518.340s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6518.345s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6519.334s] RT          : INFO     - query_internet DONE
# [+6519.444s] RT          : INFO     - query_internet DONE
# [+6519.542s] RT          : INFO     - query_internet DONE
# [+6519.885s] RT          : INFO     - query_internet DONE
# [+6525.160s] RT          : INFO     - query_internet DONE
# [+6525.954s] RT          : INFO     - query_internet DONE
# [+6528.583s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6528.588s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6528.592s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6528.597s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6528.604s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6528.609s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6529.750s] RT          : INFO     - query_internet DONE
# [+6529.772s] RT          : INFO     - query_internet DONE
# [+6529.871s] RT          : INFO     - query_internet DONE
# [+6530.187s] RT          : INFO     - query_internet DONE
# [+6530.503s] RT          : INFO     - query_internet DONE
# [+6533.842s] RT          : INFO     - query_internet DONE
# [+6534.729s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6535.613s] RT          : INFO     - query_internet DONE
# [+6536.563s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6536.567s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6537.586s] RT          : INFO     - query_internet DONE
# [+6537.837s] RT          : INFO     - query_internet DONE
# [+6538.443s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6538.447s] RT          : INFO     - review_thoughts DONE
# [+6551.981s] RT          : INFO     - Contact Finder DONE
# [+6551.984s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6563.588s] RT          : INFO     - Contact Finder Parser DONE
# [+6563.592s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6563.594s] RT          : INFO     - START CREATED Contact Finder
# [+6569.441s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6569.445s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6569.449s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6569.452s] RT          : INFO     - add_thought DONE
# [+6569.455s] RT          : INFO     - add_thought DONE
# [+6569.459s] RT          : INFO     - add_thought DONE
# [+6571.896s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6571.900s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6571.906s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6571.910s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6571.917s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6572.984s] RT          : INFO     - query_internet DONE
# [+6573.084s] RT          : INFO     - query_internet DONE
# [+6573.222s] RT          : INFO     - query_internet DONE
# [+6573.289s] RT          : INFO     - query_internet DONE
# [+6573.964s] RT          : INFO     - query_internet DONE
# [+6576.976s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6576.982s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6576.986s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6576.992s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6576.997s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6577.003s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6577.009s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6577.015s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6577.020s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6577.026s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6577.031s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6578.040s] RT          : INFO     - query_internet DONE
# [+6578.124s] RT          : INFO     - query_internet DONE
# [+6578.155s] RT          : INFO     - query_internet DONE
# [+6578.194s] RT          : INFO     - query_internet DONE
# [+6578.198s] RT          : INFO     - query_internet DONE
# [+6578.216s] RT          : INFO     - query_internet DONE
# [+6578.221s] RT          : INFO     - query_internet DONE
# [+6578.297s] RT          : INFO     - query_internet DONE
# [+6578.489s] RT          : INFO     - query_internet DONE
# [+6578.567s] RT          : INFO     - query_internet DONE
# [+6578.732s] RT          : INFO     - query_internet DONE
# [+6581.174s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6581.179s] RT          : INFO     - add_thought DONE
# [+6581.949s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6581.955s] RT          : INFO     - review_thoughts DONE
# [+6590.273s] RT          : INFO     - Contact Finder DONE
# [+6590.277s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6633.378s] RT          : INFO     - Contact Finder Parser DONE
# [+6633.381s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6633.383s] RT          : INFO     - START CREATED Contact Finder
# [+6637.043s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6637.048s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6637.052s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6637.055s] RT          : INFO     - add_thought DONE
# [+6637.060s] RT          : INFO     - add_thought DONE
# [+6637.063s] RT          : INFO     - add_thought DONE
# [+6639.506s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6639.510s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6639.515s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6639.520s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6639.526s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6640.777s] RT          : INFO     - query_internet DONE
# [+6640.781s] RT          : INFO     - query_internet DONE
# [+6640.951s] RT          : INFO     - query_internet DONE
# [+6642.501s] RT          : INFO     - query_internet DONE
# [+6645.983s] RT          : INFO     - query_internet DONE
# [+6648.196s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6648.200s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6648.205s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6648.211s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6648.216s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6648.222s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6648.228s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6649.269s] RT          : INFO     - query_internet DONE
# [+6649.353s] RT          : INFO     - query_internet DONE
# [+6649.388s] RT          : INFO     - query_internet DONE
# [+6649.436s] RT          : INFO     - query_internet DONE
# [+6649.461s] RT          : INFO     - query_internet DONE
# [+6649.503s] RT          : INFO     - query_internet DONE
# [+6654.688s] RT          : INFO     - query_internet DONE
# [+6655.559s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6656.948s] RT          : INFO     - query_internet DONE
# [+6657.749s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6658.858s] RT          : INFO     - query_internet DONE
# [+6659.578s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6660.562s] RT          : INFO     - query_internet DONE
# [+6661.305s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6662.326s] RT          : INFO     - query_internet DONE
# [+6663.029s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6663.949s] RT          : INFO     - query_internet DONE
# [+6664.666s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6665.961s] RT          : INFO     - query_internet DONE
# [+6666.610s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6667.762s] RT          : INFO     - query_internet DONE
# [+6668.386s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6669.893s] RT          : INFO     - query_internet DONE
# [+6670.610s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6671.549s] RT          : INFO     - query_internet DONE
# [+6672.182s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6673.169s] RT          : INFO     - query_internet DONE
# [+6674.136s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6675.278s] RT          : INFO     - query_internet DONE
# [+6676.066s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6677.102s] RT          : INFO     - query_internet DONE
# [+6677.886s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6678.262s] RT          : INFO     - query_internet DONE
# [+6683.550s] RT          : INFO     - Contact Finder CREATED resolve_thoughts
# [+6683.557s] RT          : INFO     - resolve_thoughts DONE
# [+6702.949s] RT          : INFO     - Contact Finder DONE
# [+6702.952s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6714.512s] RT          : INFO     - Contact Finder Parser DONE
# [+6714.512s] RT.Validation: WARNING  - You have set max_tool_calls to None. The llm will be able to make unlimited tool calls.
# [+6714.512s] RT          : INFO     - START CREATED Contact Finder
# [+6719.038s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6719.042s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6719.046s] RT          : INFO     - Contact Finder CREATED add_thought
# [+6719.049s] RT          : INFO     - add_thought DONE
# [+6719.052s] RT          : INFO     - add_thought DONE
# [+6719.057s] RT          : INFO     - add_thought DONE
# [+6721.481s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6724.139s] RT          : INFO     - query_internet DONE
# [+6725.167s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6726.313s] RT          : INFO     - query_internet DONE
# [+6727.700s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6729.341s] RT          : INFO     - query_internet DONE
# [+6730.213s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6732.909s] RT          : INFO     - query_internet DONE
# [+6733.999s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6735.105s] RT          : INFO     - query_internet DONE
# [+6736.055s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6742.561s] RT          : INFO     - query_internet DONE
# [+6743.590s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6749.257s] RT          : INFO     - query_internet DONE
# [+6750.232s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6755.390s] RT          : INFO     - query_internet DONE
# [+6756.273s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6762.495s] RT          : INFO     - query_internet DONE
# [+6763.691s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6764.746s] RT          : INFO     - query_internet DONE
# [+6770.153s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6770.160s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6770.164s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6770.167s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6770.174s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6770.179s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6770.186s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6771.142s] RT          : INFO     - query_internet DONE
# [+6771.146s] RT          : INFO     - query_internet DONE
# [+6771.163s] RT          : INFO     - query_internet DONE
# [+6771.185s] RT          : INFO     - query_internet DONE
# [+6771.185s] RT          : INFO     - query_internet DONE
# [+6771.233s] RT          : INFO     - query_internet DONE
# [+6771.402s] RT          : INFO     - query_internet DONE
# [+6773.135s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6773.142s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6773.147s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6773.153s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6773.158s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6773.162s] RT          : INFO     - Contact Finder CREATED query_internet
# [+6774.166s] RT          : INFO     - query_internet DONE
# [+6774.175s] RT          : INFO     - query_internet DONE
# [+6774.233s] RT          : INFO     - query_internet DONE
# [+6774.348s] RT          : INFO     - query_internet DONE
# [+6774.379s] RT          : INFO     - query_internet DONE
# [+6774.762s] RT          : INFO     - query_internet DONE
# [+6775.560s] RT          : INFO     - Contact Finder CREATED review_thoughts
# [+6775.566s] RT          : INFO     - review_thoughts DONE
# [+6789.671s] RT          : INFO     - Contact Finder DONE
# [+6789.674s] RT          : INFO     - START CREATED Contact Finder Parser
# [+6802.422s] RT          : INFO     - Contact Finder Parser DONE
# [+6802.425s] RT.Session  : INFO     - Saving execution info to .railtracks\data\sessions\809549b1-effe-4a3d-8c43-15c22fb08083.json

# %%
for company_name, contact_list in companies.items():
    print(f"Company: {company_name} - Contacts Found: {','.join([f'{x.full_name}, {x.title}' for x in contact_list])}")
# Out:
# Company: CaseWare International - Contacts Found: Sam High, Chief Technology Officer (CTO),Danielle Supkis Cheek, Vice President, Head of Analytics and AI,Ronald Lau, Group Product Manager,D Kartik Narayanan, Senior Product Owner,Craig Thorvardson, Senior Software Development Manager,Matt Swann, Product Manager,Ricardo Navarrete, AI Platform Lead,Nabiha H, CPA, CA, Product Owner
# Company: Deep Genomics - Contacts Found: Brendan Frey, Founder & Chief Innovation Officer,Asha Rostamianfar, Head of Engineering,Shawdee Eshghi, Vice President, Platform Biology,Leen Schafer, PhD, Director, Platform Engineering & AI,Stephanie Meler, Product,Albi Celaj, ML/AI Lead,Greg Hoffman, Chief Scientific Officer,Jean M Macklaim, PhD, Product Manager & Scientist,Varun Lodaya, Machine Learning Engineer II,Jill Vandenbosch, Head of AI Product
# Company: FREDsense Technologies - Contacts Found: David Lloyd, CEO and Co-Founder,Emily Hicks, Co-Founder and Chief Operating Officer,Margaret (Maggie) Renaud-Young, Lead Scientist - R&D and Cofounder,Melanie McClare, Chief Commercial Officer,Brooks Magnowski, VP of Sales,Steven Naylor, Product Manager - PFAS Field Analysis,Mhairi McDonald, Technical Program Manager,April Woods, Research Scientist,Lisa Oberding, Co-Founder (former), Project Manager & Research Associate,Paul Mintchev, Director Of Engineering (former)
# Company: Scispot - Contacts Found: Guru Singh, Founder & CEO,Satya Singh, Co-Founder, CTO & CPO (Chief Product Officer),Rashik S., Principal Engineer, Fullstack and AI,Saurabh Sharma, Team Lead & Full Stack Engineer,Adrien Takada, Customer Success Manager (CSM) / Product,Hannah Trub, Product and Customer Success Manager,Apoorv Sharma, Growth Manager
# Company: Rose Rocket - Contacts Found: Alexander Luksidadi, CTO & Co-Founder,David Connolly, VP Engineering,Christopher McTague, Director of Engineering,John Fernandes, Director of Engineering,Norair Nor-Arevian, Staff Engineer / Architect; Platform Engineering,Serhii Panchyshyn, Software Architect (AI/ML),Diana Carroll, Director of Product,Ryan Marr, Director of Product Management, Platform,Milos Svilaric, AI Product Manager,Victoria Henri, Engineering Manager | Platform | Mobile
# Company: OpenUnit - Contacts Found: Taylor Cooney, Founder & CEO,Lucas Playford, Co-Founder & COO (Product),Oleh Hulei, Software Engineer (former contributor)
# Company: Notch Therapeutics - Contacts Found: Christopher Bond, Chief Scientific Officer,Daniel Kirouac, Director, Systems Biology,Emily Titus, Senior Vice President, Technical Operations,Shrinidh Joshi, Director, Process Development,Elizabeth Csaszar, Senior Director, Technical Operations,Gregory Block, Senior Vice President, Corporate Development (Former),Siemon Ng, Head, Molecular Biology Centre (prior); Strategic Leader, Biologics Manufacturing & Quality,Estelle deJager, Senior Manager, Administrative Services
# Company: Farmers Edge - Contacts Found: Manoj Regmi, VP, Digital Ag | Cloud | AI | Data/Platform,Jay Kinnaird, Vice President of Enterprise Technology,Matt Jensen, Director of Data Science & Innovation,Brad Grier, Principal Architect,Charulatha Ravichandran, Director, Solution Architecture,Mahmudul (Hasan), Head of Data Engineering & Web Services,Jamie Denbow, Product Manager,Dan Person, Manager of Product Development,Siva Avvaru, Director of Strategic Partnerships (Managed Services, Data Science),Zachary Zambreski, R&D in Digital Agriculture,Michael Thompson, Possible Product/Tech,Kevin Grant, Technical Software Architect/Chief Data Officer (previous),Patrick Visser, Laboratory Director
# Company: Cyclica - Contacts Found: Jason Mitakidis, Innovator & Technology Entrepreneur (Executive/CTO functions),Steve Constable, Associate Director Software Engineering (formerly Director of Technology, Team Lead),Ankur Vazirani, Engineering Lead – Platform Engineering,Stephen MacKinnon, Vice President, Applied ML,Ali Madani, Director of Machine Learning (was also Team Lead, ML),Julie Owen, Team Leader, Drug Discovery,Maria Elena Garcia Ochagavia, Machine Learning Team Lead (now at Recursion, ex-Cyclica),Zhaleh Safikhani, Machine Learning Scientist Team Lead,Farnoosh Khodakarami, Senior Data Scientist and Machine Learning Engineer (ex-ML Lead)
# Company: Hopper - Contacts Found: Joost Ouwerkerk, Co-Founder & Chief Technology Officer (CTO),Anwesha Bhattacharjee, SVP - Product, Travel,Ajand Saadatnejadi, Director of Engineering,Isabela Ozamiz, Senior Software Engineering Manager,Arek Manoukian, Principal Software Developer,Elena Velichkova, Principal Product Manager, Hotels,Rachel Farkas, Senior Product Manager – Platform Technology,Pearce Herchenrader, Senior Product Manager,Sungho Yoon, Senior Product Manager,Maxim Bublis, Platform Engineering Leader

# %% [markdown]
# impo
